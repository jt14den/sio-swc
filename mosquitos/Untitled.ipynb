# %%
# %matplotlib inline

# %%
import analyze

# %%
data = analyze.create_mosquitos_vs_tempC_plot("A3_mosquito_data.csv")
# Out:
# loading A3_mosquito_data.csv
# Saving A3_mosquito_data_mosquitos_vs_tempC.png

# %%
data
# Out:
#     year  temperature  rainfall  mosquitos  temperature_c
# 0   1960           76       191         93      24.444444
# 1   1961           73       249        109      22.777778
# 2   1962           81       112         73      27.222222
# 3   1963           78       113         72      25.555556
# 4   1964           81       159         89      27.222222
# 5   1965           87       222        109      30.555556
# 6   1966           72       103         68      22.222222
# 7   1967           77       176         92      25.000000
# 8   1968           89       236        114      31.666667
# 9   1969           88       283        128      31.111111
# 10  1970           89       151         89      31.666667
# 11  1971           71       121         72      21.666667
# 12  1972           88       267        124      31.111111
# 13  1973           85       211        102      29.444444
# 14  1974           75       101         67      23.888889
# ...
